# %%
from utils.vacancies import (
    fetch_vacancies, 
    process_vacancies, 
    analyze_vacancies, 
    store_vacancies
)

# %%
vacancies = fetch_vacancies()
print(vacancies)
# Out:
# [{'CODIGO_VACANTE': '1625951277-123', 'TITULO_VACANTE': 'AUXILIAR DE ALIMENTOS ORIENTE 24/05/2025', 'DESCRIPCION_VACANTE': 'Comfenalco Antioquia requiere para su equipo de trabajo Auxiliar de alimentos para el hotel y parque ecolÃ³gico Piedras Blancas.   Funciones:  -Organizar y preparar la elaboraciÃ³n de los alimentos, controlando la calidad, cantidad y presentaciÃ³n de los mismos, de acuerdo con los parÃ¡metros establecidos en las recetas Standard, garantizando los estÃ¡ndares de calidad e higiene que se deben tener en cuenta en la preparaciÃ³n de los mismos.  -Preparar el mise en place, con el fin de realizar la preparaciÃ³n de los alimentos, haciendo adecuado uso de los insumos, evitando el desperdicio, teniendo en cuenta la informaciÃ³n de las recetas y del formato control de eventos, en relaciÃ³n a los programas, actividades y demanda de usuario.  Nivel de estudio: Bachiller. Salario: Entre $ 1.536.000 y $1.682.000 Experiencia: MÃ\xadnimo 1 aÃ±o en preparaciÃ³n de alimentos Ti
# ...

# %%
df = process_vacancies(vacancies)
df
# Out:
#     CODIGO_VACANTE                                     TITULO_VACANTE  \
# 0   1625951277-123           AUXILIAR DE ALIMENTOS ORIENTE 24/05/2025
# 1     1626390240-5  Aprendiz CESDE TÃ©cnico laboral como asistente...
# 2    1626417565-10                                Ingeniero Residente
# 3     1626473584-1    AUXILIAR ADMINISTRATIVO - EL CARMEN DE BOLÃ�VAR
# 4       1886370194  MEDELLIN - ////// :: AUXILIAR DE ENFERMERIA CU...
# 5       1886491406                 JEFE COMERCIAL LATAM B2B ALIMENTOS
# 6       1886491419  Auxiliar de facturacion cuentas medicas URGENCIAS
# 7       1886491427                           Jefe Mipe-Diversifacados
# 8       1886491466                  LIDER COMERCIAL EN SEGUROS - CALI
# 9    217449-100131                                   AUXILIAR DE OBRA
# 10        60275839  agente call center ventas, venta cruzada - con...
# 11        60275849  232798 Asesor(a) ventas Lunes a Sábado grandes...
# ...

# %%
summary_stats = analyze_vacancies(df)
summary_stats
# Out:
#                       Métrica             Valor
# 0           Total de Vacantes                50
# 1     Número de Departamentos                12
# 2     Salario Mínimo Promedio            $26.35
# 3     Salario Máximo Promedio             $1.00
# 4  Tipo de Contrato Más Común  Por obra o labor

# %%
store_vacancies(df)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/Projects/data-api-workflows/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~/Projects/data-api-workflows/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3297, in Engine.raw_connection(self)
#    3276 """Return a "raw" DBAPI connection from the connection pool.
#    3277
#    3278 The returned object is a proxied version of the DBAPI
#    (...)   3295
#    3296 """
# -> 3297 return self.pool.connect()
#
# File ~/Projects/data-api-workflows/.venv/lib/python3.12/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
# ...

# %%
print("Data processing completed successfully!")
